# %% [markdown]
# <a href="https://colab.research.google.com/github/Antoni-Pietryga/machine-learning-bootcamp/blob/master/supervised/02_basics/03_linear_regression_R2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import bibliotek

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt

np.random.seed(42)
np.set_printoptions(precision=6,suppress=True,edgeitems=30,linewidth=120,formatter=dict(float=lambda x: f'{x:.2f}'))

sns.set(font_scale=1.3)

# %% [markdown]
# #Wygenerowanie danych

# %%
from sklearn.datasets import make_regression
data, target = make_regression(n_samples=100, n_features=1, n_targets=1, noise=30.0, random_state=42)

print(f'data shape: {data.shape}')
print(f'target shape: {target.shape}')
# Out:
# data shape: (100, 1)
# target shape: (100,)

# %%
data[:5]
# Out:
# array([[0.93],
#        [0.09],
#        [-1.06],
#        [0.31],
#        [-0.48]])

# %%
target[:5]
# Out:
# array([74.59, -37.46, -16.46, 5.35, -13.21])

# %%
plt.figure(figsize=(8,6))
plt.title('Regresja liniowa')
plt.xlabel('cecha x')
plt.ylabel('zmienna docelowa')
plt.scatter(data, target, label='cecha x')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #Regresja liniowa przy użyciu sklearn

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(data,target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.score(data,target)
# Out:
# 0.7426670084336404

# %%
y_pred = regressor.predict(data)
y_pred
# Out:
# array([49.90, 7.83, -49.21, 19.15, -20.38, 35.77, -19.60, 30.53, 33.97, 53.50, 44.45, 80.13, 40.29, -7.45, -36.79,
#        8.07, -94.15, 29.07, 54.87, -127.04, 28.25, 8.33, -19.71, 49.11, 81.46, 76.53, -26.43, 1.71, -26.49, -56.11,
#        21.29, 22.22, 16.50, -22.90, -41.75, 13.30, -11.40, 21.52, 44.48, -11.04, 21.50, -30.24, 79.39, -22.33, -8.17,
#        -16.04, -11.51, -28.65, 19.88, 13.90, -12.83, 3.75, -8.17, 77.14, -15.69, 20.62, 20.00, -5.76, -8.19, -95.54,
#        19.64, -7.75, -51.63, -31.49, -69.43, 51.76, -82.46, -91.84, -24.52, 41.74, 43.98, -66.88, -70.18, -57.34,
#        -38.32, 82.19, 52.11, 15.55, 18.25, -23.63, -84.36, 9.02, 12.03, -62.69, 56.17, -2.27, -19.90, 2.82, -46.97,
#        -3.39, -53.86, 71.08, 6.86, -21.51, -19.46, 95.79, -67.50, -32.37, -0.09, -11.91])

# %%
plt.figure(figsize=(8,6))
plt.title('regresja liniowa')
plt.xlabel('cecha x')
plt.ylabel('zmienna docelowa')
plt.scatter(data,target,label='cecha x')
plt.plot(data,y_pred,color='red',label='model')
plt.legend()
plt.show()

# %%
regressor.score(data,target)
# Out:
# 0.7426670084336404

# %%
regressor.coef_
# Out:
# array([49.83])

# %%
regressor.intercept_
# Out:
# 3.4953459615809175

# %% [markdown]
# #Regresja z podziałem na zbiór treningowy i testowy

# %%
data, target = make_regression(n_samples=1000, n_features=1, n_targets=1, noise=15, random_state=42)

print(data.shape)
print(target.shape)
# Out:
# (1000, 1)
# (1000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data,target,test_size=0.25)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (750, 1)
# (250, 1)
# (750,)
# (250,)

# %%
plt.figure(figsize=(8,6))
plt.title('Regresja liniowa train vs test')
plt.xlabel('cecha x')
plt.ylabel('zmienna docelowa')
plt.scatter(X_train,y_train,label='zbior treningowy',color='gray',alpha=0.5)
plt.scatter(X_test,y_test,label='zbior testowy',color='gold',alpha=0.5)
plt.legend()
plt.plot()
# Out:
# []

# %%
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.score(X_train,y_train)
# Out:
# 0.5550440098049001

# %%
regressor.score(X_test,y_test)
# Out:
# 0.5108438585354155

# %% [markdown]
# #Regresja liniowa zbiór treningow wizualizacja

# %%
plt.figure(figsize=(8,6))
plt.title('Regresja liniowa zbiór treningowy')
plt.xlabel('cecha x')
plt.ylabel('zmienna docelowa')
plt.scatter(X_train,y_train,label='zbior treningowy',color='gray',alpha=0.5)
plt.plot(X_train,regressor.intercept_+regressor.coef_[0] * X_train,color='red')
plt.legend()
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8,6))
plt.title('Regresja liniowa zbió testowy')
plt.xlabel('cecha x')
plt.ylabel('zmienna docelowa')
plt.scatter(X_test,y_test,label='zbior testowy',color='gold',alpha=0.5)
plt.plot(X_test,regressor.intercept_+regressor.coef_[0] * X_test,color='red')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# #Predykcja na podstawie modelu

# %%
y_pred = regressor.predict(X_test)

predictions = pd.DataFrame(data={'y_true':y_test,'y_pred':y_pred})
predictions.head()
# Out:
#       y_true     y_pred
# 0  30.876983  25.601338
# 1   1.850537   5.954600
# 2  30.604981  31.624589
# 3  -9.092543 -16.490844
# 4 -36.311708 -10.800495

# %%
predictions['error'] = predictions['y_true'] -  predictions['y_pred']
predictions.head()
# Out:
#       y_true     y_pred     errors      error
# 0  30.876983  25.601338   5.275646   5.275646
# 1   1.850537   5.954600  -4.104063  -4.104063
# 2  30.604981  31.624589  -1.019608  -1.019608
# 3  -9.092543 -16.490844   7.398301   7.398301
# 4 -36.311708 -10.800495 -25.511212 -25.511212

# %%
_ = predictions['error'].plot(kind='hist',bins=50, figsize=(8,6))
